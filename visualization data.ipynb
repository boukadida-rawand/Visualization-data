# %%
import pandas as pd # Bibliothèque pour manipuler des données
import matplotlib.pyplot as plt # Bibliothèque de visualisation 
import seaborn as sns # Bibliothèque de visualisation basée sur matplotlib

# %%
# Importation des données
df= pd.read_csv("smoking.csv")
print(df.head()) #The head() function is used to get the first n rows.
#head(n=5) avec n détermine le nombre d'instances à affiche
# Out:
#    ID gender  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0   0      F   40         155          60       81.3             1.2
# 1   1      F   40         160          60       81.0             0.8
# 2   2      M   55         170          60       80.0             0.8
# 3   3      M   40         165          70       88.0             1.5
# 4   4      F   40         155          60       86.0             1.0
#
#    eyesight(right)  hearing(left)  hearing(right)  ...  hemoglobin  \
# 0              1.0            1.0             1.0  ...        12.9
# 1              0.6            1.0             1.0  ...        12.7
# 2              0.8            1.0             1.0  ...        15.8
# 3              1.5            1.0             1.0  ...        14.7
# 4              1.0            1.0             1.0  ...        12.5
#
#    Urine protein  serum creatinine   AST   ALT   Gtp  oral  dental caries  \
# ...

# %%
# Installing Seaborn
#pip install seaborn
#conda install seaborn

# %%
#Modifier la taille des axes de la figure
#fig,ax=plt.subplots(figsize=(6,6))

# %%
#Visualisation en utilisant un histogramme
sns.set(style='ticks',palette='deep', font_scale=1.1)
sns.set(style='darkgrid')
#il y a d'autres dark, bright
sns.set(palette='deep') 
#le style du label 
sns.set(font_scale=1.1) 
#alpha est utilisé pour régler la transparence
plt.hist(df['age'], bins =5, color='b', alpha=0.8)
plt.xlabel("Age")
plt.ylabel("Count")
plt.title("Histogram of age")
plt.show()

# %%
#Visualisation d'un histogramme d'age tout en montrant des groupes selon le sexe
#Pandas reset_index() est une méthode pour réinitialiser l'index d'une trame de données. 
plt.hist(df[df["gender"]=="M"]["age"].reset_index(drop=True), alpha=0.6, label="Male", color="blue")
plt.hist(df[df["gender"]=="F"]["age"].reset_index(drop=True), alpha=0.6, label="Female", color="yellow")
plt.legend()
plt.xlabel("Age")
plt.ylabel("Count")
plt.title("Histogram of age that shows several groups")
plt.show()

# %%
#Visualisation sous forme de nuage de points
plt.scatter(df["height(cm)"], df["weight(kg)"])
plt.show()

# %%
#visualisation sous forme d'histogramme de tous les données de tous les attributs
df.hist(figsize=(20,20))
plt.show()

# %%
#Visualisation boxplot
sns.boxplot(x=df['gender'], y=df['age'])
plt.show()

# %%
#Visualisation boxplot
sns.boxplot(x ='age', y ='height(cm)', data = df)
plt.show()

# %%
#Visualisation sous forme de bar
sns.countplot(x ='gender', data = df)
plt.show()

# %%
#Visualisation sous forme scatterplot
sns.stripplot(x ='height(cm)', y ='weight(kg)', data = df, jitter = True, dodge = True)
plt.legend(['height(cm)', 'weight(kg)'])
plt.show()

# %%
#sns.set_style('darkgrid')
sns.scatterplot( data=df, x='height(cm)',  y='weight(kg)', hue='gender')
plt.show()

# %%
sns.kdeplot (data=df, x='age',hue='gender', multiple="stack")
plt.show()

# %%
#Afficher les statistiques
df.describe()
# Out:
#                  ID           age    height(cm)    weight(kg)     waist(cm)  \
# count  55692.000000  55692.000000  55692.000000  55692.000000  55692.000000
# mean   27845.500000     44.182917    164.649321     65.864936     82.046418
# std    16077.039933     12.071418      9.194597     12.820306      9.274223
# min        0.000000     20.000000    130.000000     30.000000     51.000000
# 25%    13922.750000     40.000000    160.000000     55.000000     76.000000
# 50%    27845.500000     40.000000    165.000000     65.000000     82.000000
# 75%    41768.250000     55.000000    170.000000     75.000000     88.000000
# max    55691.000000     85.000000    190.000000    135.000000    129.000000
#
#        eyesight(left)  eyesight(right)  hearing(left)  hearing(right)  \
# count    55692.000000     55692.000000   55692.000000    55692.000000
# mean         1.012623         1.007443       1.025587        1.026144
# std          0.486873         0.485964       0.157902        0.159564
# ...
